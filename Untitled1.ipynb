# %%
#START TIME 12:10

import os
import xarray as xr 
import numpy as np 
import torch 
from torch.utils.data import Dataset, DataLoader 
import torch.nn as nn 
import torch.nn.functional as F 
import matplotlib.pyplot as plt 
import cartopy.crs as ccrs 
import cartopy.feature as cfeature 
import math 
from einops import rearrange 
import sys 
sys.path.insert(0, "../u-cast") 
import sys 
sys.path.append('../evaluation') 
import indices, diagnostics 
from ucast.ucast import UNetBlock, DhariwalUNet 
from ucast import training 
from train import train

# %%
model = DhariwalUNet(in_channels=15, out_channels=1, block_sparse_attention=False, base="convolutional")

# %%
train(model, model_name="ucast_test", domain="SA", stochasticity="dropout")
# Out:
# SA
# Y_MEAN=295.9868, Y_STD=6.7740
# [Stage 1] steps_per_epoch: 160
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 train(model, model_name="ucast_test", domain="SA", stochasticity="dropout")
#
# File /mnt/primary/downscaling-repos/CORDEX-ML-Bench/train.py:225, in train(model, var_target, training_experiment, epochs, domain, model_name, stochasticity)
#     223 ckpt_dir = "./models"
#     224 if is_first:
# --> 225     final_stage1_ckpt, stage1_history = train_stage1(
#     226         model, data["dataloader_train"], data["dataset_training"], device,
#     227         lat_weights=None, ckpt_dir=ckpt_dir, domain=domain, model_name=model_name
#     228     )
#     229     final_stage2ckpt, prev_domain, stage2_history = train_stage2(
#     230         model, data["dataloader_train"], data["dataset_training"], device,
#     231         stage1_ckpt_path=final_stage1_ckpt, lat_weights=None,
#     232         ckpt_dir=ckpt_dir, domain=domain, model_name=model_name, stochasticity=stochasticity
#     233     )
#     234     is_first=False
#
# File /mnt/primary/downscaling-repos/CORDEX-ML-Bench/ucast/training.py:89, in train_stage1(model, dataloader_train, dataset_training, device, prev_domain, max_epochs, lat_weights, ckpt_dir, use_muon, domain, model_name)
#      86 # Handle scaling issues with fp16
#      87 handle_fp16(scaler, loss_batch, model, adamw_opt, muon_opt, scheduler_adamw, scheduler_muon)
# ---> 89 ema.update(model)
#      90 epoch_loss += batch_size * loss_batch.item()
#      91 global_step += 1
#
# File /opt/miniconda3/envs/CORDEX-ML-Bench/lib/python3.10/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File /mnt/primary/downscaling-repos/CORDEX-ML-Bench/ucast/utils.py:493, in EMA.update(self, model)
#     491 for k, v in model.state_dict().items():
#     492     if v.dtype.is_floating_point:
# --> 493         self.shadow[k].mul_(self.decay).add_(v, alpha=1 - self.decay)
#     494     else:
#     495         self.shadow[k] = v.clone()
#
# KeyboardInterrupt:

# %%
from evaluate import evaluate_model
evaluate_model(model=model, 
               state_path="./models/ucast_cnn_mcdropout/SA/stage_two/downscale.pt",
               var_target="tasmax", 
               domain="SA", 
               training_experiment="ESD_pseudo_reality", 
               model_name="ucast_cnn_mcdropout",
               is_probabilistic=True,
               stochasticity="dropout",
               attention="dense")
# Out:
# SA
# /opt/miniconda3/envs/CORDEX-ML-Bench/lib/python3.10/site-packages/cartopy/io/__init__.py:242: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_physical/ne_10m_coastline.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# /opt/miniconda3/envs/CORDEX-ML-Bench/lib/python3.10/site-packages/cartopy/io/__init__.py:242: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_cultural/ne_10m_admin_0_boundary_lines_land.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# RMSE: 1.278730869293213
# Results written to results/model_performance.csv
