# %%
import os
import xarray as xr 
import numpy as np 
import torch 
from torch.utils.data import Dataset, DataLoader 
import torch.nn as nn 
import torch.nn.functional as F 
import matplotlib.pyplot as plt 
import cartopy.crs as ccrs 
import cartopy.feature as cfeature 
import math 
from einops import rearrange 
import sys 
sys.path.insert(0, "../u-cast") 
import sys 
sys.path.append('../evaluation') 
import indices, diagnostics 
from ucast.ucast import UNetBlock, DhariwalUNet 
from ucast import training 
from train import train

# %%
model = DhariwalUNet(in_channels=15, out_channels=1, block_sparse_attention=False, base="convolutional")

# %%
train(model, model_name="ucast_cnn_mcdropout", domain="SA", stochasticity="dropout")
# Out:
# SA
# Y_MEAN=295.9868, Y_STD=6.7741
# [Stage 1] Epoch 1/5 - Loss: 0.480316
# [Stage 1] Epoch 2/5 - Loss: 0.275676
# [Stage 1] Epoch 3/5 - Loss: 0.231653
# [Stage 1] Epoch 4/5 - Loss: 0.208021
# [Stage 1] Epoch 5/5 - Loss: 0.189506
# [Stage 2] Epoch 1/5 (of 5 configured) - CRPS Loss: 0.137376
# [Stage 2] Epoch 2/5 (of 5 configured) - CRPS Loss: 0.122317
# [Stage 2] Epoch 3/5 (of 5 configured) - CRPS Loss: 0.111564
# [Stage 2] Epoch 4/5 (of 5 configured) - CRPS Loss: 0.112107
# [Stage 2] Epoch 5/5 (of 5 configured) - CRPS Loss: 0.111627
# Training graph saved to: ./results/ucast_cnn_mcdropout/training/training.png

# %%
from evaluate import evaluate_model
evaluate_model(model=model, 
               state_path="./models/ucast_cnn_mcdropout/SA/stage_two/downscale.pt",
               var_target="tasmax", 
               domain="SA", 
               training_experiment="ESD_pseudo_reality", 
               model_name="ucast_cnn_mcdropout",
               is_probabilistic=True,
               stochasticity="dropout")
# Out:
# SA
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 from evaluate import evaluate_model
# ----> 2 evaluate_model(model=model,
#       3                state_path="./models/ucast_cnn_mcdropout/SA/stage_two/downscale.pt",
#       4                var_target="tasmax",
#       5                domain="SA",
#       6                training_experiment="ESD_pseudo_reality",
#       7                model_name="ucast_cnn_mcdropout",
#       8                is_probabilistic=True)
#
# File /mnt/primary/downscaling-repos/CORDEX-ML-Bench/evaluate.py:190, in evaluate_model(model, state_path, var_target, training_experiment, is_probabilistic, domain, model_name)
#     183 except:
#     184     ralsd_value = float(np.asarray(ralsd).mean())
#     186 csv_rows.append({
#     187     "model": model_name,
#     188     "domain": domain,
#     189     "stochasticity": (
# --> 190         stochasticity if is_probabilistic else "deterministic"
#     191     ),
#     192     "RMSE": mean_rmse,
#     193     "Mean_Bias": float(bias_mean[var_target].mean().values),
#     194     "P98_Bias": float(bias_p98[var_target].mean().values),
#     195     "RALSD": ralsd_value,
#     196 })
#     198 try:
#     199     os.mkdir(f"results/{model_name}/{domain}")
#
# NameError: name 'stochasticity' is not defined
